# %% [markdown]
# # HW01
#
# ## 這個作業主要的目的是希望同學們了解善用模組跟套件可以很容易取得問題的快速解。

# %% [markdown]
# ## Q1. 請使用 python 讀入 Nasdaq 公司資訊！
#
# 提示：
# 1. 請先找到 Nasdaq Company List 的 .csv 檔的網址。
# 2. 使用 pandas 套件的 read_csv 函式來讀入 .csv 檔。

# %%
import pandas as pd

# %%
url = "http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange=NASDAQ&render=download"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   Symbol                                    Name LastSale     MarketCap  \
# 0    PIH  1347 Property Insurance Holdings, Inc.    7.175  4.273980e+07
# 1   TURN                180 Degree Capital Corp.     2.03  6.317677e+07
# 2   FLWS                 1-800 FLOWERS.COM, Inc.     9.45  6.103302e+08
# 3   FCCY           1st Constitution Bancorp (NJ)       18  1.452521e+08
# 4   SRCE                  1st Source Corporation    50.87  1.319371e+09
#
#   ADR TSO IPOyear             Sector                    Industry  \
# 0     n/a    2014            Finance  Property-Casualty Insurers
# 1     n/a     n/a            Finance  Finance/Investors Services
# 2     n/a    1999  Consumer Services      Other Specialty Stores
# 3     n/a     n/a            Finance        Savings Institutions
# 4     n/a     n/a            Finance                 Major Banks
#
#                        Summary Quote  Unnamed: 9
# 0   http://www.nasdaq.com/symbol/pih         NaN
# 1  http://www.nasdaq.com/symbol/turn         NaN
# 2  http://www.nasdaq.com/symbol/flws         NaN
# 3  http://www.nasdaq.com/symbol/fccy         NaN
# 4  http://www.nasdaq.com/symbol/srce         NaN

# %% [markdown]
# ## Q2. 請使用 python 畫中山大學管理學院周邊地圖！
#
# 提示：
#
# 1. 使用 geocoder 套件來找出地址的 GPS 座標。
# 2. 使用 folium 套件來顯示地圖。

# %%
import folium

# %%
import geocoder

# %%
location = geocoder.google('中山大學管理學院').latlng

# %%
location

# %%
folium.Map(location=location, zoom_start=16)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Q3. 請使用 python 將新聞中可能的關鍵詞萃取出來！ (Bonus)
#
# 提示：
#
# 1. 使用老師提供的 util.py 來擷取鉅亨網上特定新聞的內容。
# 2. 使用 jieba 套件來擷取關鍵詞。

# %%
import util

# %%
print(util.get_news_article('https://news.cnyes.com/news/id/3949102'))
# Out:
# 美股指數期貨週四（26 日）走勢相對平淡，投資人聚焦另一系列大型企業財報數字。道瓊工業平均指數期貨上漲 43 點，標普 500 指數期貨與那斯達克 100 指數期貨分別上漲 3.00 點與下跌 2.00 點。
# 推特（Twitter）、福特（Ford）、西南航空（Southwest Airlines）與有線電視及寬頻網絡等供應商康卡斯特（Comcast）等皆於盤前公佈上季財報。其中，推特財報表現優於市場預期，推升股價盤前大漲超過 10% ，福特上季獲利同樣超出華爾街預期，股價盤前上漲 1.5% 。
# 科技界財報重頭戲也即將展開，包括亞馬遜、 Google 母公司 Alphabet 、英特爾與微軟等，預計於週四美股盤後公佈上季財報數字。
# 央行同時也是週四國際市場的重點，投資人聚焦歐洲央行（European Central Bank）貨幣政策決議，與美國聯準會（U.S. Federal Reserve）下屆主席人選的消息。
# 根據《路透社》近期公佈市場調查，較多的經濟學家預期聯準會理事鮑爾（Jerome Powell）將成為下屆聯準會主席。另外，投資人預期歐洲央行本次會議將宣佈，該央行將開始採取退出極度寬鬆貨幣政策的計畫。

# %%
news = util.get_news_article('https://news.cnyes.com/news/id/3949102')
print (news)
# Out:
# 美股指數期貨週四（26 日）走勢相對平淡，投資人聚焦另一系列大型企業財報數字。道瓊工業平均指數期貨上漲 43 點，標普 500 指數期貨與那斯達克 100 指數期貨分別上漲 3.00 點與下跌 2.00 點。
# 推特（Twitter）、福特（Ford）、西南航空（Southwest Airlines）與有線電視及寬頻網絡等供應商康卡斯特（Comcast）等皆於盤前公佈上季財報。其中，推特財報表現優於市場預期，推升股價盤前大漲超過 10% ，福特上季獲利同樣超出華爾街預期，股價盤前上漲 1.5% 。
# 科技界財報重頭戲也即將展開，包括亞馬遜、 Google 母公司 Alphabet 、英特爾與微軟等，預計於週四美股盤後公佈上季財報數字。
# 央行同時也是週四國際市場的重點，投資人聚焦歐洲央行（European Central Bank）貨幣政策決議，與美國聯準會（U.S. Federal Reserve）下屆主席人選的消息。
# 根據《路透社》近期公佈市場調查，較多的經濟學家預期聯準會理事鮑爾（Jerome Powell）將成為下屆聯準會主席。另外，投資人預期歐洲央行本次會議將宣佈，該央行將開始採取退出極度寬鬆貨幣政策的計畫。

# %%
import jieba
import jieba.analyse

# %%
words = jieba.cut(news, cut_all=False) #將news切割，存成變數words#把words中的字顯示出來

# %%
for word in words:                 #把words中的字顯示出來
    print (word)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# Loading model cost 0.815 seconds.
# Prefix dict has been built succesfully.
# 美
# 股指
# 數期
# 貨週
# 四
# （
# 26
#
# 日
# ）
# 走勢
# 相對
# 平淡
# ，
# 投資人
# 聚焦
# 另
# 一系列
# 大型
# 企業
# 財報
# 數字
# 。
# 道瓊
# 工業
# 平均
# 指數期
# 貨上
# 漲
#
# 43
#
# 點
# ，
# 標普
#
# 500
#
# 指數
# 期貨
# 與
# 那斯達克
#
# 100
#
# 指數期
# 貨分別
# 上
# 漲
#
# 3.00
#
# 點與
# 下跌
#
# 2.00
#
# 點
# 。
#
#
# 推特
# （
# Twitter
# ）
# 、
# 福特
# （
# Ford
# ）
# 、
# 西南航空
# （
# Southwest
#
# Airlines
# ）
# 與
# 有線
# 電視及
# 寬頻
# 網絡
# 等
# 供應
# 商康
# 卡斯特
# （
# Comcast
# ）
# 等
# 皆
# 於
# 盤
# 前公
# 佈
# 上季
# 財報
# 。
# 其中
# ，
# 推特財
# 報表現
# 優
# 於
# 市場
# 預期
# ，
# 推升
# 股價盤
# 前大漲
# 超過
#
# 10%
#
# ，
# 福特
# 上季
# 獲利
# 同樣
# 超出
# 華爾街
# 預期
# ，
# 股價盤
# 前
# 上
# 漲
#
# 1.5%
#
# 。
#
#
# 科技界
# 財報
# 重頭戲
# 也
# 即
# 將展
# 開
# ，
# 包括
# 亞馬遜
# 、
#
# Google
#
# 母公司
#
# Alphabet
#
# 、
# 英特
# 爾
# 與
# 微軟
# 等
# ，
# 預計
# 於
# 週四美股
# 盤後公
# 佈
# 上季
# 財報
# 數字
# 。
#
#
# 央行
# 同時
# 也
# 是
# 週四國際
# 市場
# 的
# 重點
# ，
# 投資人
# 聚焦
# 歐洲
# 央行
# （
# European
#
# Central
#
# Bank
# ）
# 貨幣
# 政策
# 決議
# ，
# 與
# 美國聯
# 準會
# （
# U
# .
# S
# .
#
# Federal
#
# Reserve
# ）
# 下屆
# 主席
# 人選
# 的
# 消息
# 。
#
#
# 根據
# 《
# 路透社
# 》
# 近期
# 公
# 佈
# 市場
# 調查
# ，
# 較
# 多
# 的
# 經濟
# 學家
# 預期
# 聯準
# 會
# 理事
# 鮑爾
# （
# Jerome
#
# Powell
# ）
# 將成
# 為
# 下屆
# 聯準
# 會
# 主席
# 。
# 另外
# ，
# 投資人
# 預期
# 歐洲
# 央行
# 本次
# 會議
# 將宣
# 佈
# ，
# 該
# 央行
# 將開始
# 採取
# 退出
# 極度
# 寬
# 鬆
# 貨
# 幣
# 政策
# 的
# 計畫
# 。

# %%
tags = jieba.analyse.extract_tags(news, 10)   #切割關鍵字，存成變數tags
print(tags)
# Out:
# ['財報', '預期', '投資人', '市場', '上季', '數字', '指數期', '股價盤', '歐洲', '下屆']

# %%
news2 =  util.get_news_article('https://news.cnyes.com/news/id/3954611?exp=b')
print (news2)
# Out:
# 到家裡附近的沃爾瑪 (Walmart) 或目標百貨 (Target) 清倉架上掃貨，再放到亞馬遜 (Amazon.com) 線上網站出售，每年也可以大筆獲利，讓原本從事會計工作的 Ryan Grant 也決定辭掉工作全心投入。
# 今年 28 歲的 Ryan Grant 接受《CNBC》專訪透露，自己現在每週花 30 小時在沃爾瑪「挑貨」至線上轉售的「靈感」，其實源自大學時期每年 2 次的教科書回購活動，他在亞馬遜網站列出書籍並銷往全美，當時年獲利 1 萬美元。他同時體認到，每份訂單的過程與包裝得付出非常多時間，因此後來決定付費使用亞馬遜物流倉儲服務。
# 剛開始， Ryan Grant 總在下班與週末時，每週投入約 10 小時，到沃爾瑪清倉架進行「調查工作」，利用 Amazon Seller app 掃描商品，買下玩具、遊戲、家用產品、廚具等各類確定「再轉售」能獲利的商品。如此每月約額外賺進 1000 美元，相當於 3 萬多新台幣，待收入增長至與會計工作薪水相當以後，他便決定於 2013 年 9 月辭掉工作。
# 而在短短 3 個月過後， Ryan Grant 每月獲利已達至 9000 美元，相當於 27 萬元新台幣。隨著業務擴增，他於 2014 年春季決定租下第一間倉儲，而當發現自己忙不過的時候，也決定聘請第 1 位員工。
# Ryan Grant 回想：「我從只有我自己，每月銷售額約 3000 到 5000 美元開始，到現在 4 年過去已是 11 人小團隊，每年銷售額超過 20 萬美元。」他也發現自己愈來愈容易瞄準最有機會套利商品，關鍵通常在於「季節性」，例如消費者通常會在萬聖節過後，全數買下折扣糖果，或於新年期間半價採購耶誕節裝飾商品。
# Ryan Grant 表示，從亞馬遜網站開始「做生意」以來，整體銷售額預計將於年底達至 800 萬美元。他也表示，剛開始的獲利多數回流至對公司的「再投資」，也曾面臨商品無法售出、閒置倉儲等困境。如今隨著事業逐漸交由團隊接管，他將自己的年薪從 15 萬美元下調至 6 萬美元，並且將多數時間致力於電商策略教學，分享自己另類的創業經驗。

# %%
news2_words = jieba.cut(news2, cut_all=False)

# %%
for word in news2_words:
    print(word)
# Out:
# 到家裡
# 附近
# 的
# 沃爾瑪
#
# (
# Walmart
# )
#
# 或目
# 標百貨
#
# (
# Target
# )
#
# 清倉
# 架上
# 掃貨
# ，
# 再
# 放到
# 亞馬遜
#
# (
# Amazon
# .
# com
# )
#
# 線上
# 網站
# 出售
# ，
# 每年
# 也
# 可以
# 大筆
# 獲利
# ，
# 讓
# 原本
# 從
# 事會計
# 工作
# 的
#
# Ryan
#
# Grant
#
# 也
# 決定
# 辭掉
# 工作
# 全心投入
# 。
#
#
# 今年
#
# 28
#
# 歲
# 的
#
# Ryan
#
# Grant
#
# 接受
# 《
# CNBC
# 》
# 專訪
# 透露
# ，
# 自己
# 現在
# 每
# 週花
#
# 30
#
# 小時
# 在
# 沃爾瑪
# 「
# 挑貨
# 」
# 至線
# 上
# 轉售
# 的
# 「
# 靈感
# 」
# ，
# 其實
# 源自
# 大學
# 時期
# 每年
#
# 2
#
# 次
# 的
# 教科
# 書
# 回購
# 活動
# ，
# 他
# 在
# 亞馬遜
# 網站
# 列出
# 書籍
# 並銷
# 往
# 全美
# ，
# 當時
# 年
# 獲利
#
# 1
#
# 萬
# 美元
# 。
# 他同
# 時體
# 認到
# ，
# 每份
# 訂單
# 的
# 過程
# 與
# 包裝
# 得
# 付出
# 非常
# 多時間
# ，
# 因此
# 後
# 來
# 決定
# 付費
# 使用
# 亞馬遜
# 物流
# 倉儲
# 服務
# 。
#
#
# 剛開始
# ，
#
# Ryan
#
# Grant
#
# 總在
# 下班
# 與
# 週末
# 時
# ，
# 每週
# 投入
# 約
#
# 10
#
# 小時
# ，
# 到
# 沃爾瑪清
# 倉架
# 進行
# 「
# 調查
# 工作
# 」
# ，
# 利用
#
# Amazon
#
# Seller
#
# app
#
# 掃描
# 商品
# ，
# 買下
# 玩具
# 、
# 遊戲
# 、
# 家用
# 產品
# 、
# 廚具
# 等
# 各類
# 確定
# 「
# 再
# 轉售
# 」
# 能
# 獲利
# 的
# 商品
# 。
# 如此
# 每月
# 約額
# 外
# 賺
# 進
#
# 1000
#
# 美元
# ，
# 相當
# 於
#
# 3
#
# 萬多
# 新
# 台幣
# ，
# 待
# 收入
# 增長
# 至
# 與
# 會計
# 工作
# 薪水
# 相當
# 以
# 後
# ，
# 他
# 便
# 決定
# 於
#
# 2013
#
# 年
#
# 9
#
# 月
# 辭
# 掉
# 工作
# 。
#
#
# 而
# 在
# 短短
#
# 3
#
# 個月過
# 後
# ，
#
# Ryan
#
# Grant
#
# 每月
# 獲利
# 已
# 達
# 至
#
# 9000
#
# 美元
# ，
# 相當
# 於
#
# 27
#
# 萬元
# 新
# 台幣
# 。
# 隨著業務
# 擴增
# ，
# 他
# 於
#
# 2014
#
# 年
# 春季
# 決定
# 租下
# 第一
# 間
# 倉儲
# ，
# 而當
# 發現
# 自己
# 忙
# 不過
# 的
# 時候
# ，
# 也
# 決定聘
# 請
# 第
#
# 1
#
# 位員工
# 。
#
#
# Ryan
#
# Grant
#
# 回想
# ：
# 「
# 我
# 從
# 只有
# 我
# 自己
# ，
# 每月
# 銷售額
# 約
#
# 3000
#
# 到
#
# 5000
#
# 美元
# 開始
# ，
# 到現
# 在
#
# 4
#
# 年過
# 去
# 已
# 是
#
# 11
#
# 人小團隊
# ，
# 每年
# 銷售額
# 超過
#
# 20
#
# 萬
# 美元
# 。
# 」
# 他
# 也
# 發現
# 自己
# 愈來
# 愈
# 容易
# 瞄準
# 最有
# 機會
# 套利
# 商品
# ，
# 關鍵
# 通常
# 在
# 於
# 「
# 季節性
# 」
# ，
# 例如
# 消費者
# 通常
# 會
# 在
# 萬聖
# 節過
# 後
# ，
# 全數
# 買
# 下
# 折扣
# 糖果
# ，
# 或
# 於
# 新
# 年期
# 間
# 半價
# 採購
# 耶誕節
# 裝飾
# 商品
# 。
#
#
# Ryan
#
# Grant
#
# 表示
# ，
# 從亞馬遜
# 網站
# 開始
# 「
# 做生意
# 」
# 以來
# ，
# 整體
# 銷售額
# 預計將
# 於
# 年底
# 達至
#
# 800
#
# 萬
# 美元
# 。
# 他
# 也
# 表示
# ，
# 剛開始
# 的
# 獲
# 利多
# 數
# 回流
# 至
# 對
# 公司
# 的
# 「
# 再
# 投資
# 」
# ，
# 也
# 曾
# 面臨
# 商品
# 無法
# 售出
# 、
# 閒置
# 倉儲
# 等
# 困境
# 。
# 如今
# 隨著
# 事業
# 逐漸
# 交由
# 團隊
# 接管
# ，
# 他將
# 自己
# 的
# 年薪
# 從
#
# 15
#
# 萬
# 美元
# 下調
# 至
#
# 6
#
# 萬
# 美元
# ，
# 並且
# 將多數
# 時間
# 致力
# 於
# 電商
# 策略
# 教學
# ，
# 分享
# 自己
# 另類
# 的
# 創業
# 經驗
# 。

# %%
tags2 = jieba.analyse.extract_tags(news2, 10)   #切割關鍵字，存成變數tags
print(tags2)
# Out:
# ['Ryan', 'Grant', '獲利', '決定', '美元', '亞馬遜', '網站', '倉儲', '相當', '銷售額']
